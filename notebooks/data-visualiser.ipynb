# %%
from DataSyncer import Data

data = Data(
    id="RX0",
    sensor_log_path="../dataset/data/chaos-bells-3/RX0-data.log",
    num_sensors=2,
    sample_rate=22050
)
# Out:
# Loading "../dataset/data/chaos-bells-3/RX0-data.log"...

# %%
ax = data.plotSensor()
ax.set_xlim(6,9)
ax.set_title("RX0 Sensor Data")
# Out:
# Text(0.5, 1.0, 'RX0 Sensor Data')
